# %% [markdown]
# <a href="https://colab.research.google.com/github/diegofdogonzalez/repositorio1-/blob/master/Clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importar librerias necesarias

import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path='/content/drive/My Drive/Procesamiento digital de imagenes/colab/images/'
os.chdir(path)
# !pwd
# graficar imagenes estaticas en el notebook
# %matplotlib inline
# Out:
# /content/drive/My Drive/Procesamiento digital de imagenes/colab/images

# %%
# Display four images
def display4(a, b, c, d, title1 = "Original", title2 ="Edited", title3 ="Edited2", title4="Edited3"):
    plt.figure(figsize=(12,4))
    plt.subplot(141), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(142), plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(143), plt.imshow(c, cmap='gray'), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(144), plt.imshow(d, cmap='gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()
  
display4(img_BGR, img_RGB, img_GRAY, img_GRAY)

# %% [markdown]
# # **BGR Color-Space**

# %%
# leer una imagen
# principle of least astonishment (surprice)
img_BGR=cv2.imread('rub07.jpg', cv2.IMREAD_COLOR)
#b,g,r = cv2.split(img_BGR)

b = img_BGR[:,:,0]
g = img_BGR[:,:,1]
r = img_BGR[:,:,2]

display4(img_BGR, b,g,r,"BGR","b","g","r")
