# %% [markdown]
# <a href="https://colab.research.google.com/github/diegofdogonzalez/repositorio1-/blob/master/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Configurar folder de imagenes de prueba**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Importar las librerias necesarias**

# %%
# importar librerias necesarias

import numpy as np
import matplotlib.pyplot as plt
import cv2

# gracias imagenes estaticas en el notebook
# %matplotlib inline

# %% [markdown]
# # **Forma habitual de leer y mostrar una imagen (error en colab)**

# %%
image = cv2.imread('/content/drive/My Drive/Procesamiento digital de imagenes/colab/images/mr-robot.jpg')
cv2.imshow("Image", image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-3-a2796bca3ee3> in <module>()
#       1 image = cv2.imread('/content/drive/My Drive/Procesamiento digital de imagenes/colab/images/mr-robot.jpg')
# ----> 2 cv2.imshow("Image", image)
#       3 cv2.waitKey(0)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# # **Arreglo error**

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/My Drive/Procesamiento digital de imagenes/colab/images/mr-robot.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=810x400 at 0x7F5A1330D320>

# %% [markdown]
# # **Cargar imagen original y visualizar con matplotlib**

# %%
# leer una imagen
# principle of least astonishment (surprice)
img_BGR=cv2.imread('/content/drive/My Drive/Procesamiento digital de imagenes/colab/images/mr-robot.jpg',cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()
